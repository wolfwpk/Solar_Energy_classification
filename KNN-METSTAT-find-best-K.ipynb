# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time

#read dataset from file(already shuffled)
data = pd.read_csv("dataCollection.csv")

number = data['USAF'].values
latitude = data['Latitude'].values
longitude = data['Longitude'].values
metstat = data['Avg hourly METSTAT in 2005 (Wh/m^2)'].values
length = number.size
train_length = 600
test_length = length - train_length
classes = np.empty(length,dtype=int)

N = 2 #No. of features

#define classes labels
C = 3 # No. of classes
for i in range(length):
    if metstat[i] < 60:
        classes[i]=0
    elif 60 <= metstat[i] < 70:
        classes[i]=1
    else:
        classes[i]=2


#split shuffled data for training and testing
x_train = longitude[:train_length]
y_train = latitude[:train_length]
classes_train = classes[:train_length]
x_test = longitude[train_length:]
y_test = latitude[train_length:]
classes_test = classes[train_length:]


# define model, which compute C linear combinations, one per classifier
def distance(x1,x2):
    a = np.linalg.norm(x1 - x2, ord = 2)
    return a


def findKNeighbors(testpoint, K):
    distances = np.zeros(train_length)
    classes_number = np.zeros((C), dtype = int)
    for train_index in range(train_length):
        distances[train_index] = distance(testpoint, point_train[train_index])
    neighbors = distances.argsort()[0:K]
    for i in range(K):
        classes_number[classes_train[neighbors[i]]] += 1
    return np.argmax(classes_number)


#train models
point_train = np.c_[x_train,y_train]
y = classes_train.T.reshape(1,-1)
point_test = np.c_[x_test,y_test]

for k in range(3,20):
    classes_classify = np.zeros(point_test.size)
    test_start = time.time()
    true = 0
    for i in range(test_length):
        classes_classify[i] = findKNeighbors(point_test[i,:], k)
        if classes_classify[i] == classes_test[i]:
            true +=1
    test_end = time.time()
    print('k=', k, 'true number:',true, 'accuracy:',round(true/test_length, 4), 'time:',round(test_end-test_start, 2))
#
# #plot test result
# colors = ['r','b','g']
# labels = ['ETR<320','320<ETR<340','ETR>340']
# plt.figure(figsize=(7,4),dpi=100)
# plt.xlabel('normalized longitude')
# plt.ylabel('normalized latitude')
# plt.xlim(-130, -60)
# plt.ylim(20, 60)
# for target in range(C):
#     plt.scatter(x_test[classes_test==target], y_test[classes_test==target], label=labels[target], c=colors[target],s=8)
#
# xp1, xp2 = np.meshgrid(np.linspace(-130, -60,100),np.linspace(20, 60, 100))
# xp1_v = xp1.reshape(-1,1)
# xp2_v = xp2.reshape(-1,1)
# Xp_data = np.append(xp1_v,xp2_v,axis=1)
# classes_area = np.zeros(xp1.size)
# for i in range(xp1.size):
#     classes_area[i] = findKNeighbors(Xp_data[i,:], 3)
# classes_area=classes_area.reshape(xp1.shape)
# plt.contourf(xp1,xp2,classes_area, alpha=.3)
# plt.legend()
# Out:
# k= 3 true number: 228 accuracy: 0.7015 time: 0.98
# k= 4 true number: 244 accuracy: 0.7508 time: 0.97
# k= 5 true number: 233 accuracy: 0.7169 time: 0.97
# k= 6 true number: 230 accuracy: 0.7077 time: 0.97
# k= 7 true number: 236 accuracy: 0.7262 time: 0.97
# k= 8 true number: 236 accuracy: 0.7262 time: 0.97
# k= 9 true number: 233 accuracy: 0.7169 time: 0.97
# k= 10 true number: 238 accuracy: 0.7323 time: 0.97
# k= 11 true number: 233 accuracy: 0.7169 time: 0.98
# k= 12 true number: 236 accuracy: 0.7262 time: 0.98
# k= 13 true number: 234 accuracy: 0.72 time: 0.97
# k= 14 true number: 240 accuracy: 0.7385 time: 0.98
# k= 15 true number: 234 accuracy: 0.72 time: 0.97
# k= 16 true number: 234 accuracy: 0.72 time: 0.98
# k= 17 true number: 236 accuracy: 0.7262 time: 0.98
# k= 18 true number: 238 accuracy: 0.7323 time: 0.97
# k= 19 true number: 236 accuracy: 0.7262 time: 0.97
